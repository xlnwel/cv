# %%
from pathlib import Path
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tf.enable_eager_execution()
tf.__version__
def image_dataset(filepath, image_size, batch_size, norm=True):
    def preprocess_image(image):
        image = tf.image.decode_jpeg(image, channels=3)
        image = tf.image.resize(image, image_size)
        if norm:
            image /= 255.0  # normalize to [0,1] range
        return image

    def load_and_preprocess_image(path):
        image = tf.read_file(path)
        return preprocess_image(image)

    all_image_paths = [str(f) for f in Path(filepath).glob('*')]
    path_ds = tf.data.Dataset.from_tensor_slices(all_image_paths)
    ds = path_ds.map(load_and_preprocess_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    ds = ds.shuffle(buffer_size = batch_size)
    ds = ds.repeat()
    ds = ds.batch(batch_size)
    ds = ds.prefetch(batch_size)

    return ds

ds = image_dataset('data/train2014', (256, 256), 32, False)
batch  = ds.make_one_shot_iterator().get_next('images')
for batch in ds:
    for img in batch:
        plt.imshow(img)
        break
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0705 10:44:59.953061 4612595008 deprecation.py:323] From <ipython-input-2-3e833f2dbfe9>:26: DatasetV1.make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_one_shot_iterator(dataset)`.
# W0705 10:45:00.441375 4612595008 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0705 10:45:00.489935 4612595008 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...
